# %% [markdown]
# <a href="https://colab.research.google.com/github/farukortes/Project_1_Insertion_Sort/blob/main/COLAB__CC1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **ERROR 1**

# %%
# Error 1: Error: Too many problems.
st=input('Enter a list of strings:')
print(st)

input_list=st.split(',')
input_list = [element.strip() for element in input_list]  # Removing extra spaces
print("User input list:", input_list)


lng=len(input_list)
print('The length of list: ', lng)


def arithmetic_arranger(list):
    """
    1- Error: Too many problems.
    # 1- length of list-- limit is 5,  Check if too many inputs are available
    # For trials  "32 + 8", "1 - 3801", "9999 + 9999", "523 - 49","523 - 49","523 - 49"  ---too many
    #   For trials "32 + 8", "1 - 3801", "9999 + 9999",---- less than 5
    """
    if lng>5:
        return print("Error: Too many problems.")
        exit()
    else:
        print("Go on, the number of items is less than 5")

arithmetic_arranger(list)

# IT WORKS

# %% [markdown]
# **ERROR 2**

# %%
# Error 2: Error: Operator must be '+' or '-'.
st=input('Enter a list of strings:')
print(st)

input_list=st.split(',')
input_list = [element.strip() for element in input_list]  # Removing extra spaces
print("User input list:", input_list)

def arithmetic_arranger(list):
#op=[]
    for x in input_list:
        val=x.split(' ')
        operator=val[1]
        print("The operator", operator)
        #op.append(operator)
        #print(op)
        if operator == '+' or operator =='-':
            print("Go on")
        else:
            print("Error: Operator must be '+' or '-'.")
            break

arithmetic_arranger(list)

#  For trials "32 * 8", "1 - 3801", "9999 + 9999"

# Jupyter--delete cell-----------esc + d + d
# Jupyter--delete cell-----------alt + enter

# IT WORKS

# %% [markdown]
# **ERROR 3**

# %%
# Error 3: Error: Numbers must only contain digits.
st=input('Enter a list of strings:')
print(st)

input_list=st.split(',')
input_list = [element.strip() for element in input_list]  # Removing extra spaces
print("User input list:", input_list)


#remove double quotes
#input_list_nq =input_list.replace('"','')
#print(input_list_nq)

def arithmetic_arranger(list):
     for x in input_list:
        x_new=x.replace('"','')
        val=x_new.split(' ')
        print('length of val',len(val))
        print(val)
        val1=val[0]
        print(val1)
        val2=val[2]
        print(val2)
        print (type(val1), type(val2))
        if (val1.isdigit()) and (val2.isdigit()):
            print("Go on")
        else:
            print("Error: Numbers must only contain digits.")
            break

arithmetic_arranger(list)

#  For trials "32 + 8", "1a - 3801", "9999 + 9999"


# Jupyter--delete cell-----------esc + d + d
# Jupyter--delete cell-----------alt + enter

# IT WORKS

# %% [markdown]
# **ERROR 4**

# %%
# Error 4: Error: Numbers cannot be more than four digits.
st=input('Enter a list of strings:')
print(st)

input_list=st.split(',')
input_list = [element.strip() for element in input_list]  # Removing extra spaces
print("User input list:", input_list)


def arithmetic_arranger(list):
     for x in input_list:
        x_new=x.replace('"','')
        val=x_new.split(' ')
        print('length of val',len(val))
        print(val)
        val1=val[0]
        print(val1)
        val2=val[2]
        print(val2)
        print (type(val1), type(val2))
        if (len(val1)<=4) and (len(val2)<=4):
            print("Go on")
        else:
            print("Error: Numbers cannot be more than four digits.")
            break

arithmetic_arranger(list)

#  For trials "32 + 8", "1 - 30801", "9999 + 9999"

# Jupyter--delete cell-----------esc + d + d
# Jupyter--delete cell-----------alt + enter

# IT WORKS

# %% [markdown]
# **COMBINE ALL ERRORS-A**

# %%
# Combine all errors
st=input('Enter a list of strings:')
print(st)

input_list=st.split(',')
input_list = [element.strip() for element in input_list]  # Removing extra spaces
print("User input list:", input_list)
input_list2=input_list

lng=len(input_list)
print('The length of list: ', lng)


def arithmetic_arranger(list):
    """
    1- Error: Too many problems.
    # 1- length of list-- limit is 5,  Check if too many inputs are available
    # For trials  "32 + 8", "1 - 3801", "9999 + 9999", "523 - 49","523 - 49","523 - 49"  ---too many
    #   For trials "32 + 8", "1 - 3801", "9999 + 9999",---- less than 5
    """
    # error 1--ok
    print("ERROR 1 STARTS HERE--------------------------------------------")

    if lng>5:
        print("Error: Too many problems.")
        return
    else:
        print("Go on, the number of items is less than 5")

    # error 2--ok
    print("ERROR 2 STARTS HERE--------------------------------------------")
    for x in input_list:
        val=x.split(' ')
        operator=val[1]
        print("The operator", operator)
        #op.append(operator)
        #print(op)
        if operator == '+' or operator =='-':
            print("Go on")
        else:
            print("Error: Operator must be '+' or '-'.")
            return
   #error 3--ok
    print("ERROR 3 STARTS HERE--------------------------------------------")
    print("User input list:", input_list)

    for x in input_list:
        x_new=x.replace('"','')
        val=x_new.split(' ')
        print('length of val',len(val))
        print(val)
        val1=val[0]
        print(val1)
        val2=val[2]
        print(val2)
        print (type(val1), type(val2))
        if (val1.isdigit()) and (val2.isdigit()):
            print("Go on")
        else:
            print("Error: Numbers must only contain digits.")
            return

    print("ERROR 4 STARTS HERE--------------------------------------------")
    for x in input_list:
        x_new=x.replace('"','')
        val=x_new.split(' ')
        print('length of val',len(val))
        print(val)
        val1=val[0]
        print(val1)
        val2=val[2]
        print(val2)
        print (type(val1), type(val2))
        if (len(val1)<=4) and (len(val2)<=4):
            print("Go on")
        else:
            print("Error: Numbers cannot be more than four digits.")
            return

    print("ERROR 4 STARTS HERE--------------------------------------------")



arithmetic_arranger(list)

# %% [markdown]
# **COMBINE ALL ERRORS-B**

# %%
# Combine all errors
st=input('Enter a list of strings:')
print(st)

input_list=st.split(',')
input_list = [element.strip() for element in input_list]  # Removing extra spaces
print("User input list:", input_list)
input_list2=input_list

lng=len(input_list)
print('The length of list: ', lng)


def arithmetic_arranger(list):
    """
    1- Error: Too many problems.
    # 1- length of list-- limit is 5,  Check if too many inputs are available
    # For trials  "32 + 8", "1 - 3801", "9999 + 9999", "523 - 49","523 - 49","523 - 49"  ---too many
    #   For trials "32 + 8", "1 - 3801", "9999 + 9999",---- less than 5
    """
    # error 1--ok
    print("ERROR 1 STARTS HERE--------------------------------------------")

    if lng>5:
        print("Error: Too many problems.")
        return
    else:
        print("Go on, the number of items is less than 5")

    # error 2--ok
    print("ERROR 2 STARTS HERE--------------------------------------------")
    for x in input_list:
        val=x.split(' ')
        operator=val[1]
        print("The operator", operator)
        #op.append(operator)
        #print(op)
        if operator == '+' or operator =='-':
            print("Go on")
        else:
            print("Error: Operator must be '+' or '-'.")
            return
   #error 3--ok
    print("ERROR 3 STARTS HERE--------------------------------------------")
    print("User input list:", input_list)

    for x in input_list:
        x_new=x.replace('"','')
        val=x_new.split(' ')
        print('length of val',len(val))
        print(val)
        val1=val[0]
        print(val1)
        val2=val[2]
        print(val2)
        print (type(val1), type(val2))
        if (val1.isdigit()) and (val2.isdigit()):
            print("Go on")
        else:
            print("Error: Numbers must only contain digits.")
            return

    print("ERROR 4 STARTS HERE--------------------------------------------")
    for x in input_list:
        x_new=x.replace('"','')
        val=x_new.split(' ')
        print('length of val',len(val))
        print(val)
        val1=val[0]
        print(val1)
        val2=val[2]
        print(val2)
        print (type(val1), type(val2))
        if (len(val1)<=4) and (len(val2)<=4):
            print("Go on")
        else:
            print("Error: Numbers cannot be more than four digits.")
            return

    print("CONVERSION RULES START HERE------------------------------------")



arithmetic_arranger(list)

# %% [markdown]
# **COMBINE ALL ERRORS-1**

# %%
# Combine all errors-1
st=input('Enter a list of strings:')
print(st)

input_list=st.split(',')
input_list = [element.strip() for element in input_list]  # Removing extra spaces
print("User input list:", input_list)
input_list2=input_list

lng=len(input_list)
print('The length of list: ', lng)


def arithmetic_arranger(list):
    """
    1- Error: Too many problems.
    # 1- length of list-- limit is 5,  Check if too many inputs are available
    # For trials  "32 + 8", "1 - 3801", "9999 + 9999", "523 - 49","523 - 49","523 - 49"  ---too many
    #   For trials "32 + 8", "1 - 3801", "9999 + 9999",---- less than 5
    """
    # error 1--ok
    print("ERROR 1 STARTS HERE--------------------------------------------")

    if lng>5:
        print("Error: Too many problems.")
        return
    else:
        print("Go on, the number of items is less than 5")

    # error 2--ok
    print("ERROR 2 STARTS HERE--------------------------------------------")
    for x in input_list:
        val=x.split(' ')
        operator=val[1]
        print("The operator", operator)
        #op.append(operator)
        #print(op)
        if operator == '+' or operator =='-':
            print("Go on")
        else:
            print("Error: Operator must be '+' or '-'.")
            return
   #error 3--ok
    print("ERROR 3 STARTS HERE--------------------------------------------")
    print("User input list:", input_list)

    for x in input_list:
        x_new=x.replace('"','')
        val=x_new.split(' ')
        print('length of val',len(val))
        print(val)
        val1=val[0]
        print(val1)
        val2=val[2]
        print(val2)
        print (type(val1), type(val2))
        if (val1.isdigit()) and (val2.isdigit()):
            print("Go on")
        else:
            print("Error: Numbers must only contain digits.")
            return

    print("ERROR 4 STARTS HERE--------------------------------------------")
    for x in input_list:
        x_new=x.replace('"','')
        val=x_new.split(' ')
        print('length of val',len(val))
        print(val)
        val1=val[0]
        print(val1)
        val2=val[2]
        print(val2)
        print (type(val1), type(val2))
        if (len(val1)<=4) and (len(val2)<=4):
            print("Go on")
        else:
            print("Error: Numbers cannot be more than four digits.")
            return

    print("CONVERSION RULES--------------------------------------------")

# Rule 1: A single space bw the operator and the longest of the two operand..

    for x in input_list:
            x_new=x.replace('"','')
            val=x_new.split(' ')
            print('length of val',len(val))
            print(val)
            val1=val[0]
            print(val1)
            val2=val[2]
            dig=[val1, val2] # put two values in a row
            max_string = max(dig, key=int) # to find which one with maximum digits
            print(f"The string with the highest numerical value is '{max_string}'")
            len1=len(max_string)# length of strings with max number of digits
            print(len1)
            min_string=min(dig, key=int)
            print(f"The string with the lowest numerical value is '{min_string}'")

            #min_string = [x for x in dig if x != max_string] # Find the small one. i.e. for "32 + 8" case, find 8
            #print(small_one)
            # formatted_text=f"{max_string}\n{min_string}"
            print(max_string.rjust(6))
            combined=f"{val[1]}{' '}{min_string}" # bottom
            print(combined.rjust(6)) # print bottom aligned right

arithmetic_arranger(list)


# Notlar
# Bu kodda gereksiz özellikler var. Operandlardan max digit sayısına
# sahip olanın üste gelmesi gerekmez. Bir sonraki kodda bu düzeltilecek.
# "32 + 8", "1 - 3801"

# %% [markdown]
# **COMBINE ALL ERRORS-2A**

# %%
#Combine all errors-2
st=input('Enter a list of strings:')
print(st)

input_list=st.split(',')
input_list = [element.strip() for element in input_list]  # Removing extra spaces
print("User input list:", input_list)
input_list2=input_list

lng=len(input_list)
print('The length of list: ', lng)


def arithmetic_arranger(list):
    """
    1- Error: Too many problems.
    # 1- length of list-- limit is 5,  Check if too many inputs are available
    # For trials  "32 + 8", "1 - 3801", "9999 + 9999", "523 - 49","523 - 49","523 - 49"  ---too many
    #   For trials "32 + 8", "1 - 3801", "9999 + 9999",---- less than 5
    """
    # error 1--ok
    print("ERROR 1 STARTS HERE--------------------------------------------")

    if lng>5:
        print("Error: Too many problems.")
        return
    else:
        print("Go on, the number of items is less than 5")

    # error 2--ok
    print("ERROR 2 STARTS HERE--------------------------------------------")
    for x in input_list:
        val=x.split(' ')
        operator=val[1]
        print("The operator", operator)
        #op.append(operator)
        #print(op)
        if operator == '+' or operator =='-':
            print("Go on")
        else:
            print("Error: Operator must be '+' or '-'.")
            return
   #error 3--ok
    print("ERROR 3 STARTS HERE--------------------------------------------")
    print("User input list:", input_list)

    for x in input_list:
        x_new=x.replace('"','')
        val=x_new.split(' ')
        print('length of val',len(val))
        print(val)
        val1=val[0]
        print(val1)
        val2=val[2]
        print(val2)
        print (type(val1), type(val2))
        if (val1.isdigit()) and (val2.isdigit()):
            print("Go on")
        else:
            print("Error: Numbers must only contain digits.")
            return

    print("ERROR 4 STARTS HERE--------------------------------------------")
    for x in input_list:
        x_new=x.replace('"','')
        val=x_new.split(' ')
        print('length of val',len(val))
        print(val)
        val1=val[0]
        print(val1)
        val2=val[2]
        print(val2)
        print (type(val1), type(val2))
        if (len(val1)<=4) and (len(val2)<=4):
            print("Go on")
        else:
            print("Error: Numbers cannot be more than four digits.")
            return

    print("CONVERSION RULES--------------------------------------------")

# Rule 1: A single space bw the operator and the longest of the two operand..

    for x in input_list:
            x_new=x.replace('"','')
            val=x_new.split(' ')
            #print('length of val',len(val))
            #print(val)
            val1=val[0]
            #print(val1)
            val2=val[2]
            dig=[val1, val2] # put two values in a row
            max_string = max(dig, key=int)
            #print("Max length of digit: ",len(max_string))
            #top
            #print(val[0].rjust(7))
            s1=val[0].rjust(7)
            #print(s1)
            #bottom
            deg=len(val1)-len(val2)
            if deg>=0:
                deg=len(val1)-len(val2)+1
            elif deg<0:
                deg=1
            sec=val[1]+" "*deg+val2

            #print(sec.rjust(7))
            s2=sec.rjust(7)
            #print(s2)
            # dashes
            dashes="-"*(len(max_string)+2)
            #print(dashes.rjust(7))
            s3=dashes.rjust(7)
            #print(s3)
            #sum
            sum1=str(int(val1)+int(val2))
            #print(sum1.rjust(7))
            s4=sum1.rjust(7)
            #print(s4)
            print('************************************')
            """print(s1)
            print(s2)
            print(s3)
            print(s4)
            """
            combined_text = f"{s1}\n{s2}\n{s3}\n{s4}"

            print(combined_text, end='    ')


            print()
            """
            #print(val1.rjust(6))
            print(val[0].rjust(7))
            second=val[1]+" "+val2
            print(second.rjust(7))
            #combined=f"{val[1]}{' '}{val2}" # bottom
            #print(combined.rjust(7)) # print bottom aligned right
            dashes="-"*(len(max_string)+2)
            print(dashes.rjust(7))
            """
            """

            max_string = max(dig, key=int) # to find which one with maximum digits
            print(f"The string with the highest numerical value is '{max_string}'")
            len1=len(max_string)# length of strings with max number of digits
            print(len1)
            min_string=min(dig, key=int)
            print(f"The string with the lowest numerical value is '{min_string}'")

            #min_string = [x for x in dig if x != max_string] # Find the small one. i.e. for "32 + 8" case, find 8
            #print(small_one)
            # formatted_text=f"{max_string}\n{min_string}"
            print(max_string.rjust(6))
            combined=f"{val[1]}{' '}{min_string}" # bottom
            print(combined.rjust(6)) # print bottom aligned right
          """
arithmetic_arranger(list)


# Notlar
# Bu kodda gereksiz özellikler var. Operandlardan max digit sayısına
# sahip olanın üste gelmesi gerekmez. Bir sonraki kodda bu düzeltilecek.
# "32 + 8", "1 - 3801"

# %% [markdown]
# **COMBINE ALL ERRORS-2B**

# %%
#Combine all errors-2
st=input('Enter a list of strings:')
print(st)

input_list=st.split(',')
input_list = [element.strip() for element in input_list]  # Removing extra spaces
print("User input list:", input_list)
input_list2=input_list

lng=len(input_list)
print('The length of list: ', lng)


def arithmetic_arranger(list):
    """
    1- Error: Too many problems.
    # 1- length of list-- limit is 5,  Check if too many inputs are available
    # For trials  "32 + 8", "1 - 3801", "9999 + 9999", "523 - 49","523 - 49","523 - 49"  ---too many
    #   For trials "32 + 8", "1 - 3801", "9999 + 9999",---- less than 5
    """
    # error 1--ok
    print("ERROR 1 STARTS HERE--------------------------------------------")

    if lng>5:
        print("Error: Too many problems.")
        return
    else:
        print("Go on, the number of items is less than 5")

    # error 2--ok
    print("ERROR 2 STARTS HERE--------------------------------------------")
    for x in input_list:
        val=x.split(' ')
        operator=val[1]
        print("The operator", operator)
        #op.append(operator)
        #print(op)
        if operator == '+' or operator =='-':
            print("Go on")
        else:
            print("Error: Operator must be '+' or '-'.")
            return
   #error 3--ok
    print("ERROR 3 STARTS HERE--------------------------------------------")
    print("User input list:", input_list)

    for x in input_list:
        x_new=x.replace('"','')
        val=x_new.split(' ')
        print('length of val',len(val))
        print(val)
        val1=val[0]
        print(val1)
        val2=val[2]
        print(val2)
        print (type(val1), type(val2))
        if (val1.isdigit()) and (val2.isdigit()):
            print("Go on")
        else:
            print("Error: Numbers must only contain digits.")
            return

    print("ERROR 4 STARTS HERE--------------------------------------------")
    for x in input_list:
        x_new=x.replace('"','')
        val=x_new.split(' ')
        print('length of val',len(val))
        print(val)
        val1=val[0]
        print(val1)
        val2=val[2]
        print(val2)
        print (type(val1), type(val2))
        if (len(val1)<=4) and (len(val2)<=4):
            print("Go on")
        else:
            print("Error: Numbers cannot be more than four digits.")
            return

    print("CONVERSION RULES--------------------------------------------")

# Rule 1: A single space bw the operator and the longest of the two operand..

    for x in input_list:
            x_new=x.replace('"','')
            val=x_new.split(' ')
            #print('length of val',len(val))
            #print(val)
            val1=val[0]
            #print(val1)
            val2=val[2]
            dig=[val1, val2] # put two values in a row
            max_string = max(dig, key=int)
            #print("Max length of digit: ",len(max_string))
            #top
            #print(val[0].rjust(7))
            s1=val[0].rjust(7)
            #print(s1)
            #bottom
            deg=len(val1)-len(val2)
            if deg>=0:
                deg=len(val1)-len(val2)+1
            elif deg<0:
                deg=1
            sec=val[1]+" "*deg+val2

            #print(sec.rjust(7))
            s2=sec.rjust(7)
            #print(s2)
            # dashes
            dashes="-"*(len(max_string)+2)
            #print(dashes.rjust(7))
            s3=dashes.rjust(7)
            #print(s3)
            #sum
            sum1=str(int(val1)+int(val2))
            #print(sum1.rjust(7))
            s4=sum1.rjust(7)
            #print(s4)
            print('************************************')
            """print(s1)
            print(s2)
            print(s3)
            print(s4)
            """


            print(s1, s2, s3, s4,sep='\n')
            print(end=' ')



            """
            #print(val1.rjust(6))
            print(val[0].rjust(7))
            second=val[1]+" "+val2
            print(second.rjust(7))
            #combined=f"{val[1]}{' '}{val2}" # bottom
            #print(combined.rjust(7)) # print bottom aligned right
            dashes="-"*(len(max_string)+2)
            print(dashes.rjust(7))
            """
            """

            max_string = max(dig, key=int) # to find which one with maximum digits
            print(f"The string with the highest numerical value is '{max_string}'")
            len1=len(max_string)# length of strings with max number of digits
            print(len1)
            min_string=min(dig, key=int)
            print(f"The string with the lowest numerical value is '{min_string}'")

            #min_string = [x for x in dig if x != max_string] # Find the small one. i.e. for "32 + 8" case, find 8
            #print(small_one)
            # formatted_text=f"{max_string}\n{min_string}"
            print(max_string.rjust(6))
            combined=f"{val[1]}{' '}{min_string}" # bottom
            print(combined.rjust(6)) # print bottom aligned right
          """
arithmetic_arranger(list)


# Notlar
# Bu kodda gereksiz özellikler var. Operandlardan max digit sayısına
# sahip olanın üste gelmesi gerekmez. Bir sonraki kodda bu düzeltilecek.
# "32 + 8", "1 - 3801"

# %% [markdown]
# **Diğer Örnek Kodlar**

# %%
# Define a list of value pairs
values = [[3, 4], [45, 56], [7, 8], [123, 456]]

# Iterate through the list and format/print each pair in two columns with a 5-space interval
for value_pair in values:
    print("{:<10} {:<10}".format(value_pair[0], value_pair[1]))

# %%
# Define a list of value pairs
values = [[3, 4], [45, 56], [7, 8], [123, 456]]

# Iterate through the list and format/print each pair vertically in two columns with a 5-space interval
for value_pair in values:
    print("{:<10} {:<10}".format(value_pair[0], value_pair[1]))
    print()
